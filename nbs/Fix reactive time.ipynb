# %%
import opt_mo
import random

import time

# %%
import axelrod as axl

# %%
import numpy as np

# %%
import sympy as sym

# %%
axl.seed(6)
opponents = [[np.round(random.random(), 3) for _ in range(4)] for _ in range(1)]

# %%
best = opt_mo.reactive_best_response(opponents=opponents)
# Out:
# -(-0.019*p_1 - 0.117)*(0.013*p_1**2 - 0.023*p_1 + 1.472)*(2*(-0.019*p_1 - 0.117)*(0.007*p_1**2 - 0.026*p_1 - 0.408)*(0.015*p_1**2 - 0.035*p_1 + 0.999) + (0.007*p_1 + 0.506)*(0.007*p_1**2 - 0.026*p_1 - 0.408)*(0.013*p_1**3 + 0.024*p_1**2 - 0.314*p_1 + 0.067) + ((-0.019*p_1 - 0.117)*(0.013*p_1**2 - 0.023*p_1 + 1.472) + (0.007*p_1 + 0.506)*(0.007*p_1**2 - 0.026*p_1 - 0.408))*(-0.039*p_1**3 - 0.072*p_1**2 + 0.942*p_1 - 0.201) + ((-0.019*p_1 - 0.117)*(0.013*p_1**3 + 0.024*p_1**2 - 0.314*p_1 + 0.067) + (0.007*p_1**2 - 0.026*p_1 - 0.408)**2)*(0.013*p_1**2 - 0.023*p_1 + 1.472) - 0.019*(-0.026*p_1**3 - 0.048*p_1**2 + 0.628*p_1 - 0.134)*(-0.013*p_1**3 - 0.024*p_1**2 + 0.314*p_1 - 0.067) + (-0.013*p_1**3 - 0.024*p_1**2 + 0.314*p_1 - 0.067)**3 - 0.019*(-0.013*p_1**3 - 0.024*p_1**2 + 0.314*p_1 - 0.067)**2) + 0.019*(0.007*p_1 + 0.506)*(0.007*p_1**2 - 0.026*p_1 - 0.408)*(0.013*p_1**3 + 0.024*p_1**2 - 0.314*p_1 + 0.067)**2 - (0.007*p_1 + 0.506)*(0.019*(-0.019*p_1 - 0.117)**2*(-0.015*p_1**2 + 0.035*p
# ...

# %%
p_1 = sym.symbols('p_1')

# %%
expr = -(-0.019*p_1 - 0.117)*(0.013*p_1**2 - 0.023*p_1 + 1.472)*(2*(-0.019*p_1 - 0.117)*(0.007*p_1**2 - 0.026*p_1 - 0.408)*(0.015*p_1**2 - 0.035*p_1 + 0.999) + (0.007*p_1 + 0.506)*(0.007*p_1**2 - 0.026*p_1 - 0.408)*(0.013*p_1**3 + 0.024*p_1**2 - 0.314*p_1 + 0.067) + ((-0.019*p_1 - 0.117)*(0.013*p_1**2 - 0.023*p_1 + 1.472) + (0.007*p_1 + 0.506)*(0.007*p_1**2 - 0.026*p_1 - 0.408))*(-0.039*p_1**3 - 0.072*p_1**2 + 0.942*p_1 - 0.201) + ((-0.019*p_1 - 0.117)*(0.013*p_1**3 + 0.024*p_1**2 - 0.314*p_1 + 0.067) + (0.007*p_1**2 - 0.026*p_1 - 0.408)**2)*(0.013*p_1**2 - 0.023*p_1 + 1.472) - 0.019*(-0.026*p_1**3 - 0.048*p_1**2 + 0.628*p_1 - 0.134)*(-0.013*p_1**3 - 0.024*p_1**2 + 0.314*p_1 - 0.067) + (-0.013*p_1**3 - 0.024*p_1**2 + 0.314*p_1 - 0.067)**3 - 0.019*(-0.013*p_1**3 - 0.024*p_1**2 + 0.314*p_1 - 0.067)**2) + 0.019*(0.007*p_1 + 0.506)*(0.007*p_1**2 - 0.026*p_1 - 0.408)*(0.013*p_1**3 + 0.024*p_1**2 - 0.314*p_1 + 0.067)**2 - (0.007*p_1 + 0.506)*(0.019*(-0.019*p_1 - 0.117)**2*(-0.015*p_1**2 + 0.035*p_1 - 0.999) + 0.019*(-0.019*p_1 - 0.117)*(-0.007*p_1 - 0.506)*(0.013*p_1**3 + 0.024*p_1**2 - 0.314*p_1 + 0.067) + 0.000361*(-0.019*p_1 - 0.117)*(-0.007*p_1 - 0.506) + 0.019*(-0.019*p_1 - 0.117)*(-0.013*p_1**2 + 0.023*p_1 - 1.472)*(0.007*p_1**2 - 0.026*p_1 - 0.408) + (-0.007*p_1 - 0.506)*((-0.019*p_1 - 0.117)*(-0.007*p_1 - 0.506)*(0.007*p_1**2 - 0.026*p_1 - 0.408) + (-0.019*p_1 - 0.117)*(0.013*p_1**3 + 0.024*p_1**2 - 0.314*p_1 + 0.067)**2) + ((-0.019*p_1 - 0.117)**2*(-0.007*p_1 - 0.506) + 2*(-0.019*p_1 - 0.117)*(0.007*p_1**2 - 0.026*p_1 - 0.408)*(0.013*p_1**3 + 0.024*p_1**2 - 0.314*p_1 + 0.067))*(-0.013*p_1**2 + 0.023*p_1 - 1.472) + (2*(-0.019*p_1 - 0.117)**2*(0.013*p_1**3 + 0.024*p_1**2 - 0.314*p_1 + 0.067) + (-0.019*p_1 - 0.117)*(0.007*p_1**2 - 0.026*p_1 - 0.408)**2)*(-0.015*p_1**2 + 0.035*p_1 - 0.999)) + 0.019*((-0.019*p_1 - 0.117)*(0.013*p_1**2 - 0.023*p_1 + 1.472) + (0.007*p_1 + 0.506)*(0.007*p_1**2 - 0.026*p_1 - 0.408))*((-0.026*p_1**3 - 0.048*p_1**2 + 0.628*p_1 - 0.134)*(-0.013*p_1**3 - 0.024*p_1**2 + 0.314*p_1 - 0.067) + (-0.013*p_1**3 - 0.024*p_1**2 + 0.314*p_1 - 0.067)**2) + 0.019*(((-0.019*p_1 - 0.117)*(0.013*p_1**3 + 0.024*p_1**2 - 0.314*p_1 + 0.067) + (0.007*p_1**2 - 0.026*p_1 - 0.408)**2)*(0.013*p_1**3 + 0.024*p_1**2 - 0.314*p_1 + 0.067) + (0.007*p_1**2 - 0.026*p_1 - 0.408)**2*(0.013*p_1**3 + 0.024*p_1**2 - 0.314*p_1 + 0.067))*(0.013*p_1**2 - 0.023*p_1 + 1.472) - (((-0.019*p_1 - 0.117)*(-0.007*p_1 - 0.506)*(0.007*p_1**2 - 0.026*p_1 - 0.408) + (-0.019*p_1 - 0.117)*(0.013*p_1**3 + 0.024*p_1**2 - 0.314*p_1 + 0.067)**2)*(0.013*p_1**3 + 0.024*p_1**2 - 0.314*p_1 + 0.067) + (0.007*p_1**2 - 0.026*p_1 - 0.408)*((-0.019*p_1 - 0.117)**2*(-0.015*p_1**2 + 0.035*p_1 - 0.999) + (-0.019*p_1 - 0.117)*(-0.007*p_1 - 0.506)*(0.013*p_1**3 + 0.024*p_1**2 - 0.314*p_1 + 0.067) + 0.019*(-0.019*p_1 - 0.117)*(-0.007*p_1 - 0.506) + (-0.019*p_1 - 0.117)*(-0.013*p_1**2 + 0.023*p_1 - 1.472)*(0.007*p_1**2 - 0.026*p_1 - 0.408)))*(0.013*p_1**2 - 0.023*p_1 + 1.472) + 0.019*(3*(-0.019*p_1 - 0.117)*(0.007*p_1**2 - 0.026*p_1 - 0.408)*(0.013*p_1**3 + 0.024*p_1**2 - 0.314*p_1 + 0.067) + ((-0.019*p_1 - 0.117)*(0.013*p_1**3 + 0.024*p_1**2 - 0.314*p_1 + 0.067) + (0.007*p_1**2 - 0.026*p_1 - 0.408)**2)*(0.007*p_1**2 - 0.026*p_1 - 0.408))*(0.015*p_1**2 - 0.035*p_1 + 0.999) - (0.015*p_1**2 - 0.035*p_1 + 0.999)*((-0.019*p_1 - 0.117)*((-0.019*p_1 - 0.117)**2*(-0.015*p_1**2 + 0.035*p_1 - 0.999) + (-0.019*p_1 - 0.117)*(-0.007*p_1 - 0.506)*(0.013*p_1**3 + 0.024*p_1**2 - 0.314*p_1 + 0.067) + 0.019*(-0.019*p_1 - 0.117)*(-0.007*p_1 - 0.506) + (-0.019*p_1 - 0.117)*(-0.013*p_1**2 + 0.023*p_1 - 1.472)*(0.007*p_1**2 - 0.026*p_1 - 0.408)) + ((-0.019*p_1 - 0.117)**2*(-0.007*p_1 - 0.506) + 2*(-0.019*p_1 - 0.117)*(0.007*p_1**2 - 0.026*p_1 - 0.408)*(0.013*p_1**3 + 0.024*p_1**2 - 0.314*p_1 + 0.067))*(0.013*p_1**3 + 0.024*p_1**2 - 0.314*p_1 + 0.067) + ((-0.019*p_1 - 0.117)*(-0.007*p_1 - 0.506)*(0.007*p_1**2 - 0.026*p_1 - 0.408) + (-0.019*p_1 - 0.117)*(0.013*p_1**3 + 0.024*p_1**2 - 0.314*p_1 + 0.067)**2)*(0.007*p_1**2 - 0.026*p_1 - 0.408)) - ((0.007*p_1 + 0.506)*((-0.019*p_1 - 0.117)**2*(-0.015*p_1**2 + 0.035*p_1 - 0.999) + (-0.019*p_1 - 0.117)*(-0.007*p_1 - 0.506)*(0.013*p_1**3 + 0.024*p_1**2 - 0.314*p_1 + 0.067) + 0.019*(-0.019*p_1 - 0.117)*(-0.007*p_1 - 0.506) + (-0.019*p_1 - 0.117)*(-0.013*p_1**2 + 0.023*p_1 - 1.472)*(0.007*p_1**2 - 0.026*p_1 - 0.408)) + ((-0.019*p_1 - 0.117)**2*(-0.007*p_1 - 0.506) + 2*(-0.019*p_1 - 0.117)*(0.007*p_1**2 - 0.026*p_1 - 0.408)*(0.013*p_1**3 + 0.024*p_1**2 - 0.314*p_1 + 0.067))*(0.015*p_1**2 - 0.035*p_1 + 0.999) + ((-0.019*p_1 - 0.117)*(-0.007*p_1 - 0.506)*(0.007*p_1**2 - 0.026*p_1 - 0.408) + (-0.019*p_1 - 0.117)*(0.013*p_1**3 + 0.024*p_1**2 - 0.314*p_1 + 0.067)**2)*(0.013*p_1**2 - 0.023*p_1 + 1.472))*(-0.039*p_1**3 - 0.072*p_1**2 + 0.942*p_1 - 0.22) - ((-0.019*p_1 - 0.117)*(-0.007*p_1 - 0.506)*(0.007*p_1 + 0.506) + (-0.019*p_1 - 0.117)*(0.007*p_1**2 - 0.026*p_1 - 0.408)*(0.015*p_1**2 - 0.035*p_1 + 0.999) + (-0.019*p_1 - 0.117)*(0.013*p_1**2 - 0.023*p_1 + 1.472)*(0.013*p_1**3 + 0.024*p_1**2 - 0.314*p_1 + 0.067))*(0.000741*p_1**3 + 0.001368*p_1**2 - 0.017898*p_1 + (-0.019*p_1 - 0.117)*(0.013*p_1**2 - 0.023*p_1 + 1.472) + (0.007*p_1 + 0.506)*(0.007*p_1**2 - 0.026*p_1 - 0.408) + (-0.026*p_1**3 - 0.048*p_1**2 + 0.628*p_1 - 0.134)*(-0.013*p_1**3 - 0.024*p_1**2 + 0.314*p_1 - 0.067) + (-0.013*p_1**3 - 0.024*p_1**2 + 0.314*p_1 - 0.067)**2 + 0.003819) + 0.019*(2*(-0.019*p_1 - 0.117)*(0.007*p_1**2 - 0.026*p_1 - 0.408)*(0.015*p_1**2 - 0.035*p_1 + 0.999) + (0.007*p_1 + 0.506)*(0.007*p_1**2 - 0.026*p_1 - 0.408)*(0.013*p_1**3 + 0.024*p_1**2 - 0.314*p_1 + 0.067) + ((-0.019*p_1 - 0.117)*(0.013*p_1**3 + 0.024*p_1**2 - 0.314*p_1 + 0.067) + (0.007*p_1**2 - 0.026*p_1 - 0.408)**2)*(0.013*p_1**2 - 0.023*p_1 + 1.472))*(-0.039*p_1**3 - 0.072*p_1**2 + 0.942*p_1 - 0.201) - 0.000361*(-0.013*p_1**3 - 0.024*p_1**2 + 0.314*p_1 - 0.067)**3

# %%
sym.degree(expr)
# Out:
# 11

# %%
expr = expr.expand()

# %%
sym.degree(expr)
# Out:
# 12

# %%
opt_mo.plot_reactive_utility(opponents=opponents, best_response_player=best);

# %%
axl.seed(6)
opponents = [[np.round(random.random(), 3) for _ in range(4)] for _ in range(2)]

# %%
best = opt_mo.reactive_best_response(opponents=opponents)
# Out:
# 0

# %%
opt_mo.plot_reactive_utility(opponents=opponents, best_response_player=best);

# %%
for i in range(3):
    axl.seed(i)
    opponents = [[np.round(random.random(), 3) for _ in range(4)] for _ in range(2)]
    best = opt_mo.reactive_best_response(opponents=opponents)
# Out:
# 0
# 0
# 0

# %%
for i in range(3):
    axl.seed(i)
    opponents = [[np.round(random.random(), 3) for _ in range(4)] for _ in range(3)]
    best = opt_mo.reactive_best_response(opponents=opponents)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-5522dfd925d5> in <module>()
#       2     axl.seed(i)
#       3     opponents = [[np.round(random.random(), 3) for _ in range(4)] for _ in range(3)]
# ----> 4     best = opt_mo.reactive_best_response(opponents=opponents)
#
# ~/rsc/Memory-size-in-the-prisoners-dilemma/src/opt_mo/reactive.py in reactive_best_response(opponents)
#     167     Calculates the best response reactive strategy using resultant theory.
#     168     """
# --> 169     solution_set = reactive_set(opponents)
#     170     solution = argmax(opponents=opponents, solution_set=solution_set)
#     171
#
# ~/rsc/Memory-size-in-the-prisoners-dilemma/src/opt_mo/reactive.py in reactive_set(opponents)
#     132
#     133     derivatives = [sym.diff(utility, i) for i in [p_1, p_2]]
# --> 134     derivatives = [expr.factor() for expr in derivatives]
# ...

# %%
# best = opt_mo.reactive_best_response(opponents=opponents)

# %%
opt_mo.plot_reactive_utility(opponents=opponents, best_response_player=best);
