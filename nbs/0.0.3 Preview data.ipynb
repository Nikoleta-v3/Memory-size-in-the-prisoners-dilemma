# %%
import sqlalchemy as sa
import pandas as pd

# %%
def read_sql_data_frame(path):
    engine = sa.create_engine("sqlite:///%s" % path)
    connection = engine.connect()

    return pd.read_sql("experiments", connection)

# %%
df = read_sql_data_frame('../data/without_gambler/the_main.db')

# %%
df.describe()
# Out:
#         exp_index  first_opponent_q_1  first_opponent_q_2  first_opponent_q_3  \
# count  600.000000          600.000000          600.000000          600.000000
# mean   699.500000            0.489007            0.507402            0.502601
# std    173.349358            0.290455            0.292337            0.280937
# min    400.000000            0.001186            0.002370            0.000538
# 25%    549.750000            0.225239            0.251069            0.271933
# 50%    699.500000            0.492573            0.522296            0.500685
# 75%    849.250000            0.730447            0.760044            0.752298
# max    999.000000            0.998462            0.998575            0.996398
#
#        first_opponent_q_4  second_opponent_q_1  second_opponent_q_2  \
# count          600.000000           600.000000           600.000000
# mean             0.499320             0.530785             0.489808
# std              0.289866             0.295137             0.280315
# min              0.001145             0.000254             0.001949
# 25%              0.254379             0.269645             0.264528
# 50%              0.480495             0.534369             0.476689
# 75%              0.769010             0.798801             0.718839
# max              0.999766             0.997671             0.999255
#
#        second_opponent_q_3  second_opponent_q_4  mem_one_p_1  \
# count           600.000000           600.000000   600.000000
# mean              0.512000             0.496100     0.279421
# std               0.289884             0.293641     0.417295
# min               0.002366             0.000720     0.000000
# 25%               0.250745             0.254005     0.000000
# 50%               0.525786             0.487515     0.000000
# 75%               0.754344             0.760176     0.641146
# max               0.997952             0.998635     1.000000
#
#                ...            mem_one_cycle_length  reactive_p_1  \
# count          ...                      600.000000    600.000000
# mean           ...                        4.745000      0.060185
# std            ...                       68.969786      0.233841
# min            ...                        1.000000      0.000000
# 25%            ...                        1.000000      0.000000
# 50%            ...                        1.000000      0.000000
# 75%            ...                        2.000000      0.000000
# max            ...                     1690.000000      1.000000
#
#        reactive_p_2  reactive_p_3  reactive_p_4  evol_reactive_p_1  \
# count    600.000000    600.000000    600.000000         600.000000
# mean       0.100258      0.060185      0.100258           0.054179
# std        0.225164      0.233841      0.225164           0.224799
# min        0.000000      0.000000      0.000000           0.000000
# 25%        0.000000      0.000000      0.000000           0.000000
# 50%        0.000000      0.000000      0.000000           0.000000
# 75%        0.026905      0.000000      0.026905           0.000000
# max        1.000000      1.000000      1.000000           1.000000
#
#        evol_reactive_p_2  evol_reactive_p_3  evol_reactive_p_4  \
# count         600.000000         600.000000         600.000000
# mean            0.025650           0.054179           0.025650
# std             0.090073           0.224799           0.090073
# min             0.000000           0.000000           0.000000
# 25%             0.000000           0.000000           0.000000
# 50%             0.000000           0.000000           0.000000
# 75%             0.000000           0.000000           0.000000
# max             0.999809           1.000000           0.999809
#
#        reactive_cycle_length
# count             600.000000
# mean                1.341667
# std                 4.768245
# min                 1.000000
# 25%                 1.000000
# 50%                 1.000000
# 75%                 1.000000
# max               117.000000
#
# [8 rows x 27 columns]

# %%
min(df.exp_index), max(df.exp_index)
# Out:
# (400, 999)

# %%
other_df = read_sql_data_frame('../data/without_gambler/main.db')

# %%
min(other_df.exp_index), max(other_df.exp_index)
# Out:
# (0, 599)

# %%
data = pd.concat([df, other_df])
data = data.sort_values(by=['exp_index'])
data = data.reset_index(drop=True)
data = data.drop_duplicates()

# %%
data.to_csv('../data/numerical_experiments_without_gambler.csv')

# %%
data.describe()
# Out:
#          exp_index  first_opponent_q_1  first_opponent_q_2  \
# count  1000.000000         1000.000000         1000.000000
# mean    499.500000            0.487114            0.507529
# std     288.819436            0.290850            0.286879
# min       0.000000            0.001186            0.000426
# 25%     249.750000            0.225239            0.252376
# 50%     499.500000            0.487043            0.522296
# 75%     749.250000            0.735435            0.751023
# max     999.000000            0.998462            0.998575
#
#        first_opponent_q_3  first_opponent_q_4  second_opponent_q_1  \
# count         1000.000000         1000.000000          1000.000000
# mean             0.506513            0.496405             0.520443
# std              0.289602            0.291581             0.291042
# min              0.000538            0.001145             0.000254
# 25%              0.254374            0.247647             0.261301
# 50%              0.519162            0.478272             0.515770
# 75%              0.763515            0.764454             0.774857
# max              0.999550            0.999766             0.998728
#
#        second_opponent_q_2  second_opponent_q_3  second_opponent_q_4  \
# count          1000.000000          1000.000000          1000.000000
# mean              0.500516             0.506080             0.493446
# std               0.282002             0.287517             0.287634
# min               0.000210             0.000403             0.000720
# 25%               0.264528             0.262221             0.248554
# 50%               0.498159             0.515061             0.487578
# 75%               0.731178             0.749466             0.750983
# max               0.999653             0.999129             0.998740
#
#        mem_one_p_1          ...            mem_one_cycle_length  reactive_p_1  \
# count  1000.000000          ...                     1000.000000   1000.000000
# mean      0.268355          ...                        3.575000      0.053408
# std       0.412731          ...                       53.461599      0.221819
# min       0.000000          ...                        1.000000      0.000000
# 25%       0.000000          ...                        1.000000      0.000000
# 50%       0.000000          ...                        1.000000      0.000000
# 75%       0.570298          ...                        2.000000      0.000000
# max       1.000000          ...                     1690.000000      1.000000
#
#        reactive_p_2  reactive_p_3  reactive_p_4  evol_reactive_p_1  \
# count   1000.000000   1000.000000   1000.000000        1000.000000
# mean       0.100361      0.053408      0.100361           0.051514
# std        0.220163      0.221819      0.220163           0.220051
# min        0.000000      0.000000      0.000000           0.000000
# 25%        0.000000      0.000000      0.000000           0.000000
# 50%        0.000000      0.000000      0.000000           0.000000
# 75%        0.036286      0.000000      0.036286           0.000000
# max        1.000000      1.000000      1.000000           1.000000
#
#        evol_reactive_p_2  evol_reactive_p_3  evol_reactive_p_4  \
# count        1000.000000        1000.000000        1000.000000
# mean            0.026964           0.051514           0.026964
# std             0.087560           0.220051           0.087560
# min             0.000000           0.000000           0.000000
# 25%             0.000000           0.000000           0.000000
# 50%             0.000000           0.000000           0.000000
# 75%             0.000000           0.000000           0.000000
# max             0.999809           1.000000           0.999809
#
#        reactive_cycle_length
# count            1000.000000
# mean                1.271000
# std                 3.719327
# min                 1.000000
# 25%                 1.000000
# 50%                 1.000000
# 75%                 1.000000
# max               117.000000
#
# [8 rows x 27 columns]

# %% [markdown]
# **with gambler**

# %%
gambler = read_sql_data_frame('../data/with_gambler/the_main.db')
